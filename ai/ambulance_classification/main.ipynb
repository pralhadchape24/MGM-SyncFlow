# %%
# 1. Import library
from inference_sdk import InferenceHTTPClient
import json

# 2. Connect to Roboflow
client = InferenceHTTPClient(
    api_url="https://serverless.roboflow.com",
    api_key="Gp7KK20Cm8qaC9sOteNN"
)

# 3. Run workflow
result = client.run_workflow(
    workspace_name="sahils-workspace-3puco",
    workflow_id="detect-and-classify-9",
    images={
        "image": "./no_ambulance.jpg"
    },
    use_cache=True
)

# 🔍 OPTIONAL: Debug (run once to understand structure)
print("\nFULL RESULT:\n")
print(json.dumps(result, indent=2))


# 4. UNIVERSAL AMBULANCE DETECTION FUNCTION
def contains_ambulance(obj):
    if isinstance(obj, dict):
        for key, value in obj.items():
            if contains_ambulance(value):
                return True

    elif isinstance(obj, list):
        for item in obj:
            if contains_ambulance(item):
                return True

    elif isinstance(obj, str):
        if "ambulance" in obj.lower():
            return True

    return False


# 5. FINAL OUTPUT
if contains_ambulance(result):
    print("\n🚑 Ambulance detected")
else:
    print("\n❌ No ambulance")
# Out:
# FULL RESULT:
#
# [
#   {
#     "output_image": "...",
#     "predictions": {
#       "image": {
#         "width": null,
#         "height": null
#       },
#       "predictions": []
#     },
#     "dynamic_crop": [],
#     "detection_predictions": {
#       "image": {
#         "width": null,
#         "height": null
#       },
#       "predictions": []
#     },
#     "classification_predictions": []
#   }
# ]
#
# ❌ No ambulance
